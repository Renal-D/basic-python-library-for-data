# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,20,0.5)
y = x**2

# %%
fig = plt.figure(figsize=(4,4), dpi=300)
ax = fig.add_axes([0,0,1,1])
plt.plot(x,y)

# %%
fig, axes = plt.subplots(2,1, figsize=(4,4), dpi = 100)

axes[0].plot(x,y)
axes[0].set_title('Axes A')

axes[1].plot(y,x)
axes[1].set_title('Axes B')
plt.tight_layout()
plt.show()

# %%
fig.savefig('Gambar.png', dpi = 300)

# %% [markdown]
# ### Menambah Legenda

# %%
fig = plt.figure(dpi=300)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label = 'Plot 1')
ax.plot(x,x**3, label = 'Plot 2')
ax.plot(x,x**5, label = 'Plot 3')
ax.plot(x,x**6, label = 'Plot 4')
ax.legend(loc=(0.3,0.2))
ax.grid()

# %%
fig = plt.figure(dpi=300)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, label = 'Plot 1', lw=3, ls='-', marker='o', markersize=5, mfc='yellow',mew=1,mec='red')
ax.plot(x,x**3, label = 'Plot 2', lw=2, ls='--', marker='+', markersize=5, mfc='blue',mew=1,mec='red')
ax.plot(x,x**4, label = 'Plot 3', lw=3, ls='-.', marker='*', markersize=5, mfc='green',mew=1,mec='red')
ax.legend(loc=(0.3,0.2))

ax.set_xlim(0,12.5) # membatasi sumbu
ax.set_ylim(0,5000)
ax.grid()
