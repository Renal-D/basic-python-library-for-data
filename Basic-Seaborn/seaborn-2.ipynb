# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataku.describe(include='O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
# Barplot (histogram)
sns.barplot(x='sex',y='fare',data=dataku);

# %%
sns.barplot(x='fare',y='sex',data=dataku);

# %%
sns.barplot(x='sex',y='fare',data=dataku, estimator=sum); #jumlah

# %%
sns.barplot(x='sex',y='fare',data=dataku, estimator=np.std); #standard deviasi

# %%
sns.countplot(x='sex',data=dataku);

# %%
sns.countplot(x='deck',hue='sex', data=dataku);

# %%
sns.countplot(x='deck',hue='sex', data=dataku, order=['A','B','C','D','F','G']);

# %%
# Boxplot (box and whiskers plot)
sns.boxplot(x='sex', y='fare', data=dataku);

# %%
sns.boxplot(x='sex', y='fare',hue='deck', hue_order=['A','B','C','D','F','G'],data=dataku);

# %%
sns.violinplot(x='sex', y='fare', data=dataku);

# %%
sns.violinplot(x='sex', y='fare',hue='deck', hue_order=['A','B','C','D','F','G'],data=dataku);

# %%
sns.violinplot(x='deck',y='fare',hue='sex',order=['A','B','C','D','F','G'], split=True ,data=dataku);

# %%
# Strip Plot
sns.stripplot(x='deck',y='fare', hue='sex',order=['A','B','C','D','F','G'],jitter=True, data=dataku);

# %%
# Swarm Plot (gabungan antara violin dan scatter)
sns.swarmplot(x='deck',y='fare', hue='sex', order=['A','B','C','D','F','G'], data=dataku);
# Out:
# C:\Users\renal\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\renal\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\renal\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='deck',y='fare', hue='sex', order=['A','B','C','D','F','G'], data=dataku);
sns.swarmplot(x='deck',y='fare', hue='sex', order=['A','B','C','D','F','G'], color='pink', data=dataku);
# Out:
# C:\Users\renal\AppData\Local\Temp\ipykernel_12536\631822421.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.swarmplot(x='deck',y='fare', hue='sex', order=['A','B','C','D','F','G'], color='pink', data=dataku);
# C:\Users\renal\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\renal\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
