# %%
import pandas as pd
import seaborn as sns

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.set()

# %%
# Distribution Plot
sns.distplot(dataku.age);
# Out:
# C:\Users\renal\AppData\Local\Temp\ipykernel_15960\4180212887.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age);

# %%
sns.distplot(dataku.age, kde= False);
# Out:
# C:\Users\renal\AppData\Local\Temp\ipykernel_15960\4253260247.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age, kde= False);

# %%
sns.distplot(dataku.age, kde= False, bins=50);
# Out:
# C:\Users\renal\AppData\Local\Temp\ipykernel_15960\3202116577.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age, kde= False, bins=50);

# %%
sns.distplot(dataku.age, kde= True, bins=100); # diagram kde akan selalu sama
# Out:
# C:\Users\renal\AppData\Local\Temp\ipykernel_15960\1525971467.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age, kde= True, bins=100); # diagram kde akan selalu sama

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.jointplot(x='age', y='fare', data= dataku);

# %%
import scipy.stats as stat

# %%
sns.jointplot(x='age',y='fare', stat_func=stat.pearson3,data=dataku);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.jointplot(x='age',y='fare', stat_func=stat.pearson3,data=dataku);
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2257, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2254 if kind.startswith("scatter"):
#    2256     joint_kws.setdefault("color", color)
# -> 2257     grid.plot_joint(scatterplot, **joint_kws)
#    2259     if grid.hue is None:
#    2260         marg_func = histplot
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1832, in JointGrid.plot_joint(self, func, **kwargs)
#    1829     self._inject_kwargs(func, kwargs, self._hue_params)
# ...
