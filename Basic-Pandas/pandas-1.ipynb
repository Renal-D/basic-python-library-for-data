# %%
pwd
# Out:
# 'D:\\PYTHON_\\data-en__\\Basic_PythonLibrary-Data_Analytics\\Basic-Pandas'

# %%
import pandas as pd

# %%
df = pd.read_csv('kapal_titanic.csv')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
df.shape
# Out:
# (891, 9)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
df.to_csv('data1_csv', index=False)

# %%
pd.read_csv('data1_csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
data_html = pd.read_html('https://en.m.wikipedia.org/wiki/List_of_stadiums_by_capacity')

# %%
type(data_html)
# Out:
# list

# %%
data_html
# Out:
# [                                                   0
#  0  This article needs to be updated. Please help ...,
#                                     Stadium       Capacity  \
#  0                 Narendra Modi Stadium[1]  132,000[2][3]
#  1              Rungrado 1st of May Stadium     115,000[4]
#  2                         Michigan Stadium     107,601[5]
#  3                           Beaver Stadium     106,572[6]
#  4                             Ohio Stadium     102,780[7]
#  5                               Kyle Field     102,733[8]
#  6                            Tiger Stadium     102,321[9]
#  7                          Neyland Stadium    101,915[10]
#  8   Darrell K Royal–Texas Memorial Stadium    100,119[11]
#  9                     Bryant–Denny Stadium    100,077[12]
#  10                Melbourne Cricket Ground    100,024[13]
#
#                     City (state)        Country         Region  \
#  0            Ahmedabad, Gujarat          India     South Asia
# ...

# %%
from sqlalchemy import create_engine

# %%
carmine= create_engine('sqlite:///:memory:')

# %%
df.to_sql('datasql', con= carmine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.to_sql('datasql', con= carmine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
# ...

# %%
pd.read_sql('datasql', con= carmine)
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#      deck
# 0    None
# 1       C
# 2    None
# 3       C
# ...
